# %%
# Cell 1: install + download
# !pip install pandas numpy
# !wget -q https://dataverse.harvard.edu/api/access/datafile/6180620 -O kg.csv
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Cell 2: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cell 3: run it
# %cd /content/drive/MyDrive/Colab Notebooks
# %run create_split.py
# Out:
# /content/drive/MyDrive/Colab Notebooks
# Loading PrimeKG...
#   Total edges: 8,100,498
#   Columns: ['relation', 'display_relation', 'x_index', 'x_id', 'x_type', 'x_name', 'x_source', 'y_index', 'y_id', 'y_type', 'y_name', 'y_source']
#   Unique relation types: 30
#
#   disease_phenotype_positive edges: 300,634
#   indication edges: 18,776
#
#   (disease, phenotype) pairs: 300,634
#   (disease, drug) pairs:      18,776
#
#   Diseases with ≥1 phenotype: 6744
#   Diseases with ≥1 drug:      1363
#   Eligible (both):            539
#   Phenotypes covering eligible diseases: 3518
#
#   Train diseases: 431
#   Test diseases:  108
#
#   Train disease–drug pairs: 5406
#   Test  disease–drug pairs: 1568
#
#   Unique drugs in test:  485
#   Also seen in train:   345 (71.1%)
#
# ✓ All files saved to 'split/'
# {
#   "seed": 42,
#   "test_frac": 0.2,
#   "n_eligible_diseases": 539,
#   "n_train_diseases": 431,
#   "n_test_diseases": 108,
#   "n_train_pairs": 5406,
#   "n_test_pairs": 1568,
#   "n_unique_test_drugs": 485,
#   "n_test_drugs_in_train": 345,
#   "pct_test_drugs_in_train": 71.1,
#   "n_phenotypes": 3518
# }
